# %% [markdown]
# <a href="https://colab.research.google.com/github/hossein20s/epicircle-notebooks/blob/master/beta_VAE_on_mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
sys.path.append('/content/drive/My Drive/sync/code/epicircle/python')

# %%
# !pip install pytorch_lightning test-tube
# Out:
# ...
#      |████████████████████████████████| 409kB 5.5MB/s
# ...
#      |████████████████████████████████| 2.8MB 23.7MB/s
# ...
#      |████████████████████████████████| 829kB 53.5MB/s
# ...
#      |████████████████████████████████| 276kB 50.6MB/s
# ...
#   Created wheel for test-tube: filename=test_tube-0.7.5-cp36-none-any.whl size=25357 sha256=8122e20673beb77054059e7d86a5e2d9f6b1038631f8e053ac99e149001a3d49
#   Stored in directory: /root/.cache/pip/wheels/02/52/96/c8b6f3c345cfd3284845ef50818c6996a5658006fe50e40e98
# ...
#   Created wheel for future: filename=future-0.18.2-cp36-none-any.whl size=491057 sha256=9bde4afc3a2fc4f4dd4a8cfb7b6841fb9d51f5f2bde2a713fdb56a1b44b4513f
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=d2c6eabd8f6c26e420c992e78cbcaf666229217cd9aef8902f98a379db5ff4fe
# ...

# %%
# !gdown --id 1-jaDh242DrEebKBgcTsTIuq_MnFTCmZY -O vaecheckpoint
# https://drive.google.com/file/d/1-Ydpgls5qird4878eOxWvUErHe3pJJHh/view?usp=sharing
# !wget -O vaecheckpoint --no-check-certificate 'https://drive.google.com/uc?export=download&id=1MPO5VLif6qs6VKrbIOHhMe1w4wrssJfz'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-jaDh242DrEebKBgcTsTIuq_MnFTCmZY
# To: /content/vaecheckpoint
# 40.1MB [00:00, 70.7MB/s]

# %%
import yaml
import importlib
import epicircle
importlib.reload(epicircle)
from epicircle.vae.run import vae_main

with open('/content/drive/My Drive/sync/code/epicircle/python/epicircle/vae/configs/bhvae.yaml', 'r') as file:
    try:
        config = yaml.safe_load(file)
    except yaml.YAMLError as exc:
        print(exc)
    vae_main(config, runningInColab=True)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: GPU available but not used. Set the --gpus flag when calling the script.
#   warnings.warn(*args, **kwargs)
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/distributed.py:37: UserWarning: Could not log computational graph since the `model.example_input_array` attribute is not set or `input_array` was not given
#   warnings.warn(*args, **kwargs)
#
#   | Name  | Type    | Params
# ----------------------------------
# 0 | model | BetaVAE | 2 M
# ======= Training BetaVAE =======
# Test tube created git tag: tt_BetaVAE_H_v3
# ...
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
# ...
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
# ...
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
# ...

# %%
file_name = 'vae_exp*t.py'  #@param {type: "string"}

# !cd '/content/drive/My Drive/sync/code/epicircle/python/' && find -name "*$file_name" -exec cat -n {} \;
# Out:
#      1	from abc import ABC
#      2	from typing import TypeVar
#      3
#      4	import pandas
#      5	import pytorch_lightning as pl
#      6	import torch
#      7	import torchvision.utils as vutils
#      8	from pytorch_lightning.loggers import TestTubeLogger
#      9	from torch import optim
#     10	from torch.utils.data import DataLoader
#     11	from torchvision import transforms
#     12	from torchvision.datasets import CelebA, MNIST
#     13
#     14	from epicircle.util.animation import Animator
#     15	from epicircle.util.utils import data_loader
#     16	from epicircle.vae.models.base import BaseVAE
#     17
#     18	Tensor = TypeVar('torch.tensor')
#     19
#     20
#     21	class VAE_Experiment(pl.LightningModule, ABC):
#     22
#     23	    def __init__(self,
#     24	                 vae_model: BaseVAE,
#     25	                 params: dict,
#     26	                 logger: TestTubeLogger,
#     27	                 ) -> None:
# ...

# %%
# !cp ckpt/* '/content/drive/My Drive/sync/result/BetaVAE_H/version_3/checkpoints'
